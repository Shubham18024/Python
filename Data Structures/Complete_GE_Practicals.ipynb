# %% [markdown]
# # "Aakhir ho kyu nahi rahi??"

# %%
from IPython.display import Image, display

image_path = "alakh.gif"  # Change this to your image path
display(Image(filename=image_path, width=400, height=100))  # Adjust width and height as needed

# %% [markdown]
# ![Alt Text](alakh.gif)

# %% [markdown]
# # Padh Likh Lo
# # Please
