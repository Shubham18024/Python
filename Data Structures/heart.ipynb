# %%
import turtle
import turtle as trt
from turtle import *
import time

win = Screen()
win.setup(1250, 650)
time.sleep(1)
win.bgcolor('white')
time.sleep(1)

a = trt.Turtle()
a.color('blue', 'red')
a.shape('arrow')
a.penup()
time.sleep(1)
a.goto(-600, 250)
a.width(8)

# Remove B A B Y letters and U design

# Heart shape function
def curve():
    for i in range(200):
        a.right(1)
        a.forward(1)

def heart():
    a.fillcolor('red')
    a.begin_fill()
    a.left(140)
    a.forward(113)
    win.bgcolor('#ffcccc')
    curve()
    a.left(120)
    curve()
    a.forward(112)
    a.end_fill()

# Draw heart
a.penup()
a.setpos(0, -100)
a.pendown()
a.width(4)
a.shape('turtle')
a.color('white', 'yellow')
heart()

# Rose Flower
a.penup()
a.setpos(400, 245)
a.pendown()
a.width(2)
a.color('black', 'red')
a.shape('circle')
a.right(45)  # Tilt the flower slightly

a.fillcolor("red")
a.begin_fill()
a.circle(10, 180)
a.circle(25, 110)
a.left(50)
a.circle(60, 45)
a.circle(20, 170)
a.right(24)
a.fd(30)
a.left(10)
a.circle(30, 110)
a.fd(20)
a.left(40)
a.circle(90, 70)
a.circle(30, 150)
a.right(30)
a.fd(15)
a.circle(80, 90)
a.left(15)
a.fd(45)
a.right(165)
a.fd(20)
a.left(155)
a.circle(150, 80)
a.left(50)
a.circle(150, 90)
a.end_fill()

# Petals
a.left(150)
a.circle(-90, 70)
a.left(20)
a.circle(75, 105)
a.setheading(60)
a.circle(80, 98)
a.circle(-90, 40)
a.left(180)
a.circle(90, 40)
a.circle(-80, 98)
a.setheading(-83)

# Leaves
a.fd(30)
a.left(90)
a.fd(25)
a.left(45)
a.fillcolor("green")
a.begin_fill()
a.circle(-80, 90)
a.right(90)
a.circle(-80, 90)
a.end_fill()
a.right(135)
a.fd(60)
a.left(180)
a.fd(85)
a.left(90)
a.fd(80)
a.right(90)
a.right(45)
a.fillcolor("green")
a.begin_fill()
a.circle(80, 90)
a.left(90)
a.circle(80, 90)
a.end_fill()
a.left(135)
a.fd(60)
a.left(180)
a.fd(60)
a.right(90)
a.circle(200, 60)

# Text message
pen = trt.Turtle('classic')

def txt():
    pen.up()
    pen.setpos(-600, 120)  # Increased space between heart and text
    pen.down()
    pen.color('deep pink')
    pen.write("Hi Yashika,", font=("Courier", 16, "bold"))  # Made text bold
    time.sleep(1.5)

    pen.up()
    pen.setpos(-600, 80)  # Adjusted position
    pen.down()
    pen.color('red')
    pen.write("First of all sorry us din ke lie aur un sabhi cheezon ke lie", font=("Courier", 15, "bold"))
    time.sleep(1.5)

    pen.up()
    pen.setpos(-600, 45)  # Adjusted position
    pen.down()
    pen.write("jisse tumhe bura laga ho... chahe wo pair maarna ya hurt karna ho.", font=("Courier", 15, "bold"))
    time.sleep(2)

    pen.up()
    pen.setpos(-600, 15)  # Adjusted position
    pen.down()
    pen.color('darkred')
    pen.write("Maine kabhi jaanboojh ke nahi kiya...", font=("Courier", 16, "bold"))
    time.sleep(2)

    pen.up()
    pen.setpos(-600, -20)  # Adjusted position
    pen.down()
    pen.color('purple')
    pen.write("Tum pehli ho jisse college mein itni achhi bonding hui.", font=("Courier", 15, "bold"))
    time.sleep(1.5)

    pen.up()
    pen.setpos(-600, -50)  # Adjusted position
    pen.down()
    pen.write("Hamesha meri care karne ke liye bahut bahut thank you.", font=("Courier", 15, "bold"))
    time.sleep(2)

    pen.up()
    pen.setpos(-600, -80)  # Adjusted position
    pen.down()
    pen.write("Main kabhi nahi bhoolunga tujhe yaar...", font=("Courier", 15, "bold"))
    time.sleep(2)

    pen.up()
    pen.setpos(-600, -110)  # Adjusted position
    pen.down()
    pen.write("Specially wo smile... ", font=("Courier", 15, "bold"))
    time.sleep(2)

    pen.up()
    pen.setpos(-600, -140)  # Adjusted position
    pen.down()
    pen.write("Aur agar koi marne wali baat kar doon to uspe naaraz hona,", font=("Courier", 15, "bold"))
    time.sleep(2)

    pen.up()
    pen.setpos(-600, -170)  # Adjusted position
    pen.down()
    pen.write("ki aisa mat bola karo... kya pata Saraswati baithi ho.", font=("Courier", 15, "bold"))
    time.sleep(2)

    pen.up()
    pen.setpos(-600, -200)  # Adjusted position
    pen.down()
    pen.write("Kitni bhooli aur cute lagti thi tu uss time 😔", font=("Courier", 15, "bold"))
    time.sleep(2)

    pen.up()
    pen.setpos(-600, -230)  # Adjusted position
    pen.down()
    pen.write("Tu beautiful to hai yaar...", font=("Courier", 15, "bold"))
    time.sleep(2)

    pen.up()
    pen.setpos(-600, -260)  # Adjusted position
    pen.down()
    pen.write("Itna kuch uss nanhi si t-shirt mein kaise likhta 😅", font=("Courier", 15, "bold"))
    time.sleep(2)

    pen.up()
    pen.setpos(-600, -290)  # Adjusted position
    pen.down()
    pen.write("Isliye poora code design kara dopahar se...", font=("Courier", 15, "bold"))
    time.sleep(2)

    pen.up()
    pen.setpos(-600, -320)  # Adjusted position
    pen.down()
    pen.write("Taaki bhej paau... kyunki likhne mein aalas aata hai 😔", font=("Courier", 15, "bold"))

win.title('My Cute Baby - Message for Yashika 💖')
win.bgcolor('#ecb3ff')
txt()
win.mainloop()
